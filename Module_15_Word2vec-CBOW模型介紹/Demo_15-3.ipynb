# %% [markdown]
# # CBOW模型建立

# %%
from __future__ import print_function
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index

    span = 2 * skip_window + 1 # [ skip_window target skip_window ]

    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side

    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)

    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself

        # do this num_skips (2 times)
        # do this (1 time)

        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels



for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
num_steps = 100001

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
# pick 16 samples from 100
valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    # embedding, vector for each word in the vocabulary
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Averaging embeddings accross the full context into a single embedding layer
    context_embeddings = []
    for i in range(2*skip_window):
        context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))
            
    avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False)

    # Compute the softmax loss, using a sample of the negative labels each time.
    # inputs are embeddings of the train words
    # with this loss we optimize weights, biases, embeddings

    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From C:\Users\isaac\Anaconda3\envs\test\lib\site-packages\tensorflow_core\python\training\adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From <ipython-input-7-70871a840515>:52: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Initialized
# Average loss at step 0: 7.659307
# Nearest to nine: bios, tunnel, effectiveness, breathe, henrik, decrypted, emperors, kom,
# Nearest to seven: kirsten, confinement, bizarre, chu, camino, dre, performer, libra,
# Nearest to states: amal, wahhabism, guitars, suspecting, rix, bribed, equipment, imaginary,
# Nearest to b: sloped, commoners, kocher, jenna, ghats, sewing, edema, utilization,
# Nearest to but: staves, shuttlecock, flamboyant, subgenus, conifer, paleozoic, organising, domestication,
# Nearest to five: humiliation, keeps, monatomic, unnecessary, iterations, mundi, chuppah, newsstand,
# Nearest to may: ottonian, gnostics, wei, wrestlemania, eigenvalue, parsons, austronesian, irb,
# Nearest to used: dance, revolt, neu, volunteer, welcoming, elevators, cnn, mallard,
# Nearest to pressure: bloomington, tacitus, vista, polyhedra, pcd, fours, nearer, voting,
# Nearest to fall: unsolicited, lust, gut, stroke, ibero, notate, folding, kurt,
# Nearest to gold: katha, nominate, constitutionality, repressed, illegality, normandie, legally, unheated,
# Nearest to paris: rivera, acetyl, misguided, woollen, theodore, cyclists, flying, tipping,
# Nearest to powers: erv, christopher, grouping, inaccuracy, charcoal, nem, articles, juliet,
# Nearest to event: crazy, introns, essential, option, container, iranian, attacked, discontinuity,
# Nearest to taking: syndicalist, craggy, islamism, cormen, tailored, rajasthan, atalh, yisrael,
# Nearest to woman: chipping, restrictive, kline, inaction, potable, eleusinian, rutles, eisenhower,
# Average loss at step 2000: 4.036712
# Average loss at step 4000: 3.503289
# Average loss at step 6000: 3.343000
# Average loss at step 8000: 3.191454
# Average loss at step 10000: 3.146325
# Nearest to nine: eight, six, seven, five, zero, four, two, three,
# Nearest to seven: eight, nine, six, four, five, three, two, zero,
# Nearest to states: guitars, amal, doodle, imaginary, gallagher, vocalist, daimler, suspecting,
# Nearest to b: d, utilization, toxin, commoners, psyche, taxicab, regain, khanty,
# Nearest to but: fingerings, and, did, friendliness, propulsion, subgenus, cytotoxic, could,
# Nearest to five: six, eight, nine, seven, zero, four, three, two,
# Nearest to may: would, can, could, will, alef, imprint, should, wrestlemania,
# Nearest to used: fairs, welcoming, pembroke, volunteer, pete, known, meteorologists, neu,
# Nearest to pressure: bloomington, tacitus, vista, fours, voting, cycladic, wa, polyhedra,
# Nearest to fall: unsolicited, lust, stroke, notate, gut, genesee, ibero, quasars,
# Nearest to gold: katha, legally, nominate, illegality, constitutionality, repressed, vukovar, symphonies,
# Nearest to paris: acetyl, rivera, misguided, hesitation, woollen, assesses, vdc, armory,
# Nearest to powers: erv, christopher, grouping, inaccuracy, charcoal, nem, juliet, betrayed,
# Nearest to event: crazy, introns, essential, option, container, discontinuity, nations, attacked,
# Nearest to taking: craggy, syndicalist, awarded, rajasthan, tailored, atalh, cormen, odo,
# Nearest to woman: chipping, kline, restrictive, inaction, potable, phrase, wlad, pie,
# Average loss at step 12000: 3.170759
# Average loss at step 14000: 3.127821
# Average loss at step 16000: 3.144088
# Average loss at step 18000: 3.099842
# Average loss at step 20000: 2.989467
# Nearest to nine: eight, seven, six, five, four, zero, three, aim,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to states: guitars, amal, equipment, breakdancing, primus, intangible, starboard, gallagher,
# Nearest to b: d, utilization, khanty, taxicab, toxin, commoners, f, psyche,
# Nearest to but: however, and, fingerings, though, which, while, quickly, did,
# Nearest to five: six, eight, four, seven, three, nine, zero, two,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to used: known, seen, spoken, referred, pembroke, fairs, found, volunteer,
# Nearest to pressure: tacitus, bloomington, vista, fours, cycladic, acoustics, voting, moneo,
# Nearest to fall: unsolicited, lust, stroke, doolittle, kayak, flocked, documented, takashi,
# Nearest to gold: katha, legally, illegality, vukovar, repressed, unheated, symphonies, fujimori,
# Nearest to paris: acetyl, hesitation, rivera, misguided, woollen, armory, arrays, assesses,
# Nearest to powers: erv, betrayed, inaccuracy, christopher, grouping, trilobite, nem, energized,
# Nearest to event: crazy, essential, introns, nations, discontinuity, option, container, biota,
# Nearest to taking: awarded, syndicalist, craggy, odo, tailored, numbering, atalh, assembled,
# Nearest to woman: chipping, phrase, kline, restrictive, inaction, wlad, pie, airfoil,
# Average loss at step 22000: 3.052342
# Average loss at step 24000: 3.023677
# Average loss at step 26000: 2.985338
# Average loss at step 28000: 3.016253
# Average loss at step 30000: 2.990352
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to seven: eight, six, nine, four, five, three, two, zero,
# Nearest to states: amal, intangible, kingdom, primus, guitars, breakdancing, equipment, gallagher,
# Nearest to b: d, utilization, khanty, taxicab, toxin, f, psyche, commoners,
# Nearest to but: however, and, fingerings, although, though, makes, which, chipsets,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to used: seen, known, referred, spoken, found, fairs, added, recorded,
# Nearest to pressure: tacitus, bloomington, fours, acoustics, vista, cycladic, voting, dunne,
# Nearest to fall: stroke, lust, unsolicited, kayak, planets, doolittle, flocked, assamese,
# Nearest to gold: katha, vukovar, bio, reconstructionism, fujimori, unheated, illegality, legally,
# Nearest to paris: hesitation, acetyl, rivera, misguided, woollen, armory, tubas, arrays,
# Nearest to powers: erv, betrayed, inaccuracy, nem, grouping, christopher, trilobite, statisticians,
# Nearest to event: essential, crazy, discontinuity, introns, idea, option, nations, iranian,
# Nearest to taking: awarded, odo, syndicalist, craggy, funimation, unaccompanied, numbering, napier,
# Nearest to woman: chipping, phrase, airfoil, restrictive, kline, rutles, pie, meribbaal,
# Average loss at step 32000: 2.839726
# Average loss at step 34000: 2.949488
# Average loss at step 36000: 2.936814
# Average loss at step 38000: 2.937580
# Average loss at step 40000: 2.919135
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to seven: eight, five, six, four, nine, three, zero, two,
# Nearest to states: kingdom, intangible, amal, breakdancing, primus, equipment, vocalist, kipper,
# Nearest to b: d, utilization, khanty, psyche, f, taxicab, directv, toxin,
# Nearest to but: however, and, while, although, though, buchan, hydra, therapeutic,
# Nearest to five: six, four, seven, eight, three, nine, two, zero,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to used: known, seen, referred, found, spoken, available, added, fairs,
# Nearest to pressure: tacitus, acoustics, bloomington, cycladic, vista, voting, fours, comparisons,
# Nearest to fall: stroke, kayak, lust, planets, flocked, doolittle, unsolicited, assamese,
# Nearest to gold: katha, vukovar, bio, fujimori, resting, unheated, illegality, reconstructionism,
# Nearest to paris: hesitation, tubas, acetyl, rivera, misguided, woollen, recombine, arrays,
# Nearest to powers: erv, betrayed, conferring, carbamazepine, finance, redemptive, inaccuracy, statisticians,
# Nearest to event: essential, crazy, idea, introns, discontinuity, option, container, nations,
# Nearest to taking: awarded, odo, funimation, napier, took, numbering, ethnography, unaccompanied,
# Nearest to woman: chipping, phrase, airfoil, restrictive, kline, meribbaal, rutles, pie,
# Average loss at step 42000: 2.940646
# Average loss at step 44000: 2.945185
# Average loss at step 46000: 2.902454
# Average loss at step 48000: 2.872717
# Average loss at step 50000: 2.842180
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to states: kingdom, amal, intangible, equipment, breakdancing, evo, nations, primus,
# Nearest to b: d, khanty, utilization, toxin, psyche, f, taxicab, berkshire,
# Nearest to but: however, and, although, while, buchan, though, beautifully, fingerings,
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to used: known, seen, spoken, referred, available, described, found, added,
# Nearest to pressure: tacitus, comparisons, acoustics, zee, cycladic, encryption, vista, refracting,
# Nearest to fall: stroke, planets, kayak, lust, flocked, assamese, takashi, doolittle,
# Nearest to gold: katha, bio, vukovar, fujimori, resting, reconstructionism, illegality, symphonies,
# Nearest to paris: hesitation, tubas, europe, pooling, acetyl, rivera, woollen, clementi,
# Nearest to powers: erv, betrayed, conferring, feuding, finance, redemptive, convents, strat,
# Nearest to event: essential, idea, crazy, introns, option, container, reason, nations,
# Nearest to taking: awarded, took, odo, funimation, napier, ethnography, earthquakes, numbering,
# Nearest to woman: chipping, meribbaal, phrase, airfoil, restrictive, kline, man, rutles,
# Average loss at step 52000: 2.878741
# Average loss at step 54000: 2.858841
# Average loss at step 56000: 2.852508
# Average loss at step 58000: 2.766923
# Average loss at step 60000: 2.833445
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to seven: five, eight, six, four, nine, three, zero, two,
# Nearest to states: kingdom, amal, nations, intangible, breakdancing, state, evo, parties,
# Nearest to b: d, khanty, utilization, f, psyche, alsos, taxicab, recurrence,
# Nearest to but: however, although, and, buchan, while, beautifully, though, which,
# Nearest to five: seven, four, six, eight, nine, three, zero, two,
# Nearest to may: can, could, would, will, must, should, might, cannot,
# Nearest to used: known, referred, seen, described, spoken, added, found, defined,
# Nearest to pressure: tacitus, acoustics, comparisons, zee, refracting, vista, km, encryption,
# Nearest to fall: stroke, kayak, flocked, lust, assamese, takashi, narrating, planets,
# Nearest to gold: katha, bio, vukovar, resting, fujimori, reconstructionism, dodecanese, unheated,
# Nearest to paris: tubas, hesitation, pooling, acetyl, reproduced, europe, rivera, iconoclasm,
# Nearest to powers: betrayed, erv, conferring, convents, descendants, statisticians, finance, feuding,
# Nearest to event: essential, idea, crazy, introns, option, reason, discontinuity, container,
# Nearest to taking: awarded, took, funimation, earthquakes, ethnography, odo, napier, followed,
# Nearest to woman: chipping, man, meribbaal, phrase, airfoil, spalding, utf, restrictive,
# Average loss at step 62000: 2.828932
# Average loss at step 64000: 2.776834
# Average loss at step 66000: 2.765756
# Average loss at step 68000: 2.720245
# Average loss at step 70000: 2.783392
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to seven: five, six, eight, nine, four, three, two, zero,
# Nearest to states: kingdom, nations, evo, state, gallagher, breakdancing, amal, intangible,
# Nearest to b: d, khanty, utilization, toxin, psyche, alsos, randy, taxicab,
# Nearest to but: however, although, and, which, though, while, chipsets, beautifully,
# Nearest to five: seven, six, four, eight, three, nine, zero, two,
# Nearest to may: can, could, would, will, must, might, should, cannot,
# Nearest to used: referred, seen, known, added, spoken, found, described, defined,
# Nearest to pressure: acoustics, tacitus, km, comparisons, refracting, zee, encryption, vista,
# Nearest to fall: stroke, kayak, flocked, command, lust, takashi, sais, assamese,
# Nearest to gold: katha, bio, vukovar, resting, fujimori, reconstructionism, outkast, illegality,
# Nearest to paris: hesitation, tubas, pooling, europe, acetyl, reproduced, saturday, iconoclasm,
# Nearest to powers: betrayed, conferring, convents, erv, finance, statisticians, descendants, lamanites,
# Nearest to event: idea, essential, option, introns, element, reason, crazy, discontinuity,
# Nearest to taking: awarded, took, funimation, earthquakes, followed, made, ethnography, lbs,
# Nearest to woman: man, chipping, meribbaal, phrase, spalding, solo, utf, rutles,
# Average loss at step 72000: 2.798495
# Average loss at step 74000: 2.657852
# Average loss at step 76000: 2.800895
# Average loss at step 78000: 2.818840
# Average loss at step 80000: 2.782453
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to states: kingdom, nations, state, countries, intangible, breakdancing, evo, amal,
# Nearest to b: d, khanty, utilization, alsos, f, psyche, directv, randy,
# Nearest to but: however, although, and, which, though, while, buchan, coals,
# Nearest to five: six, seven, eight, four, three, nine, zero, two,
# Nearest to may: can, could, would, might, will, must, should, cannot,
# Nearest to used: known, referred, described, seen, added, spoken, employed, responsible,
# Nearest to pressure: acoustics, km, tacitus, zee, comparisons, voltage, refracting, participates,
# Nearest to fall: stroke, kayak, flocked, assamese, narrating, takashi, planets, command,
# Nearest to gold: katha, bio, resting, vukovar, fujimori, outkast, legally, reconstructionism,
# Nearest to paris: hesitation, pooling, tubas, saturday, reproduced, woollen, europe, acetyl,
# Nearest to powers: betrayed, convents, conferring, erv, descendants, carbamazepine, dukedom, statisticians,
# Nearest to event: idea, essential, reason, option, element, introns, autopilot, zarah,
# Nearest to taking: awarded, took, earthquakes, followed, funimation, ethnography, rounded, besieged,
# Nearest to woman: man, phrase, chipping, meribbaal, solo, spalding, concert, rutles,
# Average loss at step 82000: 2.674318
# Average loss at step 84000: 2.775153
# Average loss at step 86000: 2.741330
# Average loss at step 88000: 2.758674
# Average loss at step 90000: 2.742385
# Nearest to nine: seven, eight, six, four, five, three, zero, two,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to states: kingdom, nations, countries, state, intangible, breakdancing, monographs, amal,
# Nearest to b: d, khanty, utilization, f, c, omega, taxicab, directv,
# Nearest to but: however, although, though, and, while, which, buchan, ayla,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to may: can, would, could, might, will, should, must, cannot,
# Nearest to used: referred, described, known, spoken, seen, designed, added, employed,
# Nearest to pressure: comparisons, acoustics, km, zee, participates, voltage, tacitus, temperatures,
# Nearest to fall: stroke, kayak, narrating, grow, takashi, assamese, planets, flocked,
# Nearest to gold: resting, bio, katha, vukovar, outkast, fujimori, reconstructionism, castlevania,
# Nearest to paris: hesitation, pooling, tubas, saturday, reproduced, woollen, europe, berlin,
# Nearest to powers: convents, descendants, conferring, betrayed, role, lamanites, leaders, courts,
# Nearest to event: idea, reason, essential, element, option, zarah, introns, phillies,
# Nearest to taking: took, awarded, take, funimation, rounded, followed, earthquakes, besieged,
# Nearest to woman: man, solo, meribbaal, chipping, phrase, person, spalding, concert,
# Average loss at step 92000: 2.692625
# Average loss at step 94000: 2.723436
# Average loss at step 96000: 2.705868
# Average loss at step 98000: 2.384037
# Average loss at step 100000: 2.422943
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to states: kingdom, nations, state, countries, breakdancing, intangible, gallagher, amal,
# Nearest to b: d, khanty, toxin, taxicab, randy, directv, teletype, hawkins,
# Nearest to but: however, although, though, and, while, which, beautifully, chipsets,
# Nearest to five: six, seven, four, eight, nine, three, zero, two,
# Nearest to may: can, could, would, might, should, will, must, cannot,
# Nearest to used: referred, described, spoken, employed, seen, known, added, recorded,
# Nearest to pressure: voltage, acoustics, comparisons, temperatures, zee, participates, tacitus, km,
# Nearest to fall: stroke, kayak, narrating, assamese, takashi, planets, sais, grow,
# Nearest to gold: bio, katha, resting, fujimori, outkast, vukovar, dodecanese, reconstructionism,
# Nearest to paris: hesitation, pooling, tubas, saturday, laos, europe, reproduced, berlin,
# Nearest to powers: convents, descendants, betrayed, conferring, supporters, leaders, lamanites, courts,
# Nearest to event: idea, reason, element, option, autopilot, essential, zarah, phillies,
# Nearest to taking: took, awarded, take, earthquakes, building, funimation, besieged, rounded,
# Nearest to woman: man, person, meribbaal, concert, spalding, chipping, solo, phrase,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # Gensim套件實作CBOW

# %%
import gzip
import gensim
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

data_file="./reviews_data.txt.gz"

with gzip.open ('./reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in Beijing, then you will be ok.I chose to have some breakfast in the hotel, which was really tasty and there was a good selection of dishes. There are a couple of computers to use in the communal area, as well as a pool table. There is also a small swimming pool and a gym area.I would definitely stay in this hotel again, but only if I did not plan to travel to central Beijing, as it can take a long time. The location is ok if you plan to do a lot of shopping, as there is a big shopping centre just few minutes away from the hotel and there are plenty of eating options around, including restaurants that serve a dog meat!\t\r\n"

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    print("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open (input_file, 'rb') as f:
        for i, line in enumerate (f): 

            if (i%10000==0):
                print("read {0} reviews".format (i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess (line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list (read_input (data_file))
print("Done reading data file")
# Out:
# reading file ./reviews_data.txt.gz...this may take a while
# read 0 reviews
# read 10000 reviews
# read 20000 reviews
# read 30000 reviews
# read 40000 reviews
# read 50000 reviews
# read 60000 reviews
# read 70000 reviews
# read 80000 reviews
# read 90000 reviews
# read 100000 reviews
# read 110000 reviews
# read 120000 reviews
# read 130000 reviews
# read 140000 reviews
# read 150000 reviews
# read 160000 reviews
# read 170000 reviews
# read 180000 reviews
# read 190000 reviews
# read 200000 reviews
# read 210000 reviews
# read 220000 reviews
# read 230000 reviews
# read 240000 reviews
# read 250000 reviews
# Done reading data file

# %%
documents[0]
# Out:
# ['oct',
#  'nice',
#  'trendy',
#  'hotel',
#  'location',
#  'not',
#  'too',
#  'bad',
#  'stayed',
#  'in',
#  'this',
#  'hotel',
#  'for',
#  'one',
#  'night',
#  'as',
#  'this',
#  'is',
#  'fairly',
#  'new',
#  'place',
#  'some',
#  'of',
#  'the',
#  'taxi',
#  'drivers',
#  'did',
#  'not',
#  'know',
#  'where',
#  'it',
#  'was',
#  'and',
#  'or',
#  'did',
#  'not',
#  'want',
#  'to',
#  'drive',
#  'there',
#  'once',
#  'have',
#  'eventually',
#  'arrived',
#  'at',
#  'the',
#  'hotel',
#  'was',
#  'very',
#  'pleasantly',
#  'surprised',
#  'with',
#  'the',
#  'decor',
#  'of',
#  'the',
#  'lobby',
#  'ground',
#  'floor',
#  'area',
#  'it',
#  'was',
#  'very',
#  'stylish',
#  'and',
#  'modern',
#  'found',
#  'the',
#  'reception',
#  'staff',
#  'geeting',
#  'me',
#  'with',
#  'aloha',
#  'bit',
#  'out',
#  'of',
#  'place',
#  'but',
#  'guess',
#  'they',
#  'are',
#  'briefed',
#  'to',
#  'say',
#  'that',
#  'to',
#  'keep',
#  'up',
#  'the',
#  'coroporate',
#  'image',
#  'as',
#  'have',
#  'starwood',
#  'preferred',
#  'guest',
#  'member',
#  'was',
#  'given',
#  'small',
#  'gift',
#  'upon',
#  'check',
#  'in',
#  'it',
#  'was',
#  'only',
#  'couple',
#  'of',
#  'fridge',
#  'magnets',
#  'in',
#  'gift',
#  'box',
#  'but',
#  'nevertheless',
#  'nice',
#  'gesture',
#  'my',
#  'room',
#  'was',
#  'nice',
#  'and',
#  'roomy',
#  'there',
#  'are',
#  'tea',
#  'and',
#  'coffee',
#  'facilities',
#  'in',
#  'each',
#  'room',
#  'and',
#  'you',
#  'get',
#  'two',
#  'complimentary',
#  'bottles',
#  'of',
#  'water',
#  'plus',
#  'some',
#  'toiletries',
#  'by',
#  'bliss',
#  'the',
#  'location',
#  'is',
#  'not',
#  'great',
#  'it',
#  'is',
#  'at',
#  'the',
#  'last',
#  'metro',
#  'stop',
#  'and',
#  'you',
#  'then',
#  'need',
#  'to',
#  'take',
#  'taxi',
#  'but',
#  'if',
#  'you',
#  'are',
#  'not',
#  'planning',
#  'on',
#  'going',
#  'to',
#  'see',
#  'the',
#  'historic',
#  'sites',
#  'in',
#  'beijing',
#  'then',
#  'you',
#  'will',
#  'be',
#  'ok',
#  'chose',
#  'to',
#  'have',
#  'some',
#  'breakfast',
#  'in',
#  'the',
#  'hotel',
#  'which',
#  'was',
#  'really',
#  'tasty',
#  'and',
#  'there',
#  'was',
#  'good',
#  'selection',
#  'of',
#  'dishes',
#  'there',
#  'are',
#  'couple',
#  'of',
#  'computers',
#  'to',
#  'use',
#  'in',
#  'the',
#  'communal',
#  'area',
#  'as',
#  'well',
#  'as',
#  'pool',
#  'table',
#  'there',
#  'is',
#  'also',
#  'small',
#  'swimming',
#  'pool',
#  'and',
#  'gym',
#  'area',
#  'would',
#  'definitely',
#  'stay',
#  'in',
#  'this',
#  'hotel',
#  'again',
#  'but',
#  'only',
#  'if',
#  'did',
#  'not',
#  'plan',
#  'to',
#  'travel',
#  'to',
#  'central',
#  'beijing',
#  'as',
#  'it',
#  'can',
#  'take',
#  'long',
#  'time',
#  'the',
#  'location',
#  'is',
#  'ok',
#  'if',
#  'you',
#  'plan',
#  'to',
#  'do',
#  'lot',
#  'of',
#  'shopping',
#  'as',
#  'there',
#  'is',
#  'big',
#  'shopping',
#  'centre',
#  'just',
#  'few',
#  'minutes',
#  'away',
#  'from',
#  'the',
#  'hotel',
#  'and',
#  'there',
#  'are',
#  'plenty',
#  'of',
#  'eating',
#  'options',
#  'around',
#  'including',
#  'restaurants',
#  'that',
#  'serve',
#  'dog',
#  'meat']

# %%
'''
Word2Vec model parameters

size:
The size of the dense vector to represent each token or word. If you have very limited data, then size should be a much smaller value. If you have lots of data, its good to experiment with various sizes. A value of 100-150 has worked well for me.

window:
The maximum distance between the target word and its neighboring word. If your neighbor's position is greater than the maximum window width to the left and the right, then, some neighbors are not considered as being related to the target word. In theory, a smaller window should give you terms that are more related. If you have lots of data, then the window size should not matter too much, as long as its a decent sized window.

min_count:
Minimium frequency count of words. The model would ignore words that do not statisfy the min_count. Extremely infrequent words are usually unimportant, so its best to get rid of those. Unless your dataset is really tiny, this does not really affect the model.

workers:
How many threads to use behind the scenes?

sg: sg=1 means skip-gram and sg=0 menascbow
'''
model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10, sg=0)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# 2020-03-06 00:30:38,307 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2020-03-06 00:30:38,310 : INFO : collecting all words and their counts
# 2020-03-06 00:30:38,311 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-03-06 00:30:38,649 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2020-03-06 00:30:38,975 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2020-03-06 00:30:39,437 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2020-03-06 00:30:39,880 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2020-03-06 00:30:40,364 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2020-03-06 00:30:40,883 : INFO : PROGRESS: at sentence #60000, processed 11013723 words, keeping 76781 word types
# 2020-03-06 00:30:41,297 : INFO : PROGRESS: at sentence #70000, processed 12637525 words, keeping 83194 word types
# 2020-03-06 00:30:41,630 : INFO : PROGRESS: at sentence #80000, processed 14099751 words, keeping 88454 word types
# 2020-03-06 00:30:42,001 : INFO : PROGRESS: at sentence #90000, processed 15662149 words, keeping 93352 word types
# 2020-03-06 00:30:42,376 : INFO : PROGRESS: at sentence #100000, processed 17164487 words, keeping 97881 word types
# 2020-03-06 00:30:42,741 : INFO : PROGRESS: at sentence #110000, processed 18652292 words, keeping 102127 word types
#         1.1975032 ,  0.33563402, -2.2049477 , -0.11218524, -0.28556168,
#        -0.34820792,  0.52400094,  1.414405  ,  2.5404422 ,  4.550944  ,
#        -2.6552773 , -0.9514217 , -1.428891  ,  0.53678024,  0.10785449,
#        -1.8162004 , -4.308226  ,  2.2984958 ,  3.2975404 , -0.27680567,
#        -0.2070539 , -0.2821894 ,  0.4341247 ,  0.95308256,  0.12808235,
#         0.46710795, -3.5206208 ,  1.9006801 ,  0.87947893, -0.65941733,
#        -1.2850032 ,  0.09494916,  0.388911  ,  0.39984378, -2.9494665 ,
#         1.3615822 , -1.1670321 , -2.9094312 , -0.5689286 ,  0.8641652 ,
#         2.9333036 ,  1.4651247 ,  2.1830292 ,  1.1034424 ,  0.7664948 ,
#        -3.5677774 , -1.6381148 , -1.2241825 ,  6.693606  ,  0.5849955 ,
#        -0.8776261 ,  1.5063618 ,  1.4755701 ,  2.450637  ,  2.3951862 ,
#        -2.0054696 ,  0.6695978 , -1.0776955 , -2.4433267 ,  3.539378  ,
#        -4.580513  ,  2.8802774 , -1.9826545 ,  0.19525151,  0.41873085,
#        -1.1982628 ,  2.6342103 , -1.0440441 ,  3.0978267 ,  0.3322277 ,
#         0.6592711 ,  0.72964764,  2.075986  , -0.8851874 ,  0.45126307,
#        -1.9078594 , -0.5703397 ,  2.5477402 , -1.4991769 ,  1.4575416 ,
#        -0.5858708 ,  1.8476729 , -2.6601634 , -5.193065  , -0.8054129 ,
#         1.2946274 ,  1.5536019 ,  1.6890643 , -2.6960964 , -1.2718459 ,
#        -1.4955406 ,  1.5953166 , -1.3603534 , -0.20920825,  1.6350589 ,
#         2.6994302 , -0.24296038, -1.0580125 ,  5.393678  , -0.139726  ,
#        -2.2274258 ,  2.3966768 ,  0.30764288, -0.13928849, -0.64098376,
#         0.5878703 , -2.3806446 ,  2.0233881 ,  1.2993941 ,  1.0660834 ,
#        -1.6313496 ,  1.8984088 ,  6.8542924 ,  1.6556164 ,  1.5390227 ,
#        -2.0159495 ,  0.53366065,  0.0825507 ,  4.019615  ,  4.876614  ,
#        -0.29334506,  2.3310502 , -2.271029  , -1.7367411 , -3.7675211 ,
#         0.9645328 , -2.5535347 , -2.1209376 ,  7.0712523 , -1.1938227 ,
#         1.3792678 ,  2.421373  ,  3.1334753 , -3.4282484 , -2.670342  ,
#         0.9598102 ,  2.6829956 ,  0.8455313 , -0.68702394, -1.5641097 ],
#       dtype=float32)

# %%
# get everything related to stuff on the bed
w1 = ["bed",'sheet']
w2 = ['couch']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# 2020-03-06 08:23:20,359 : INFO : precomputing L2-norms of word weight vectors
# [('duvet', 0.637520432472229),
#  ('quilt', 0.6242080926895142),
#  ('mattress', 0.6185429692268372),
#  ('blanket', 0.6083204746246338),
#  ('pillowcase', 0.5914482474327087),
#  ('pillow', 0.5897761583328247),
#  ('matress', 0.5891723036766052),
#  ('sheets', 0.574439525604248),
#  ('comforter', 0.5325940251350403),
#  ('wool', 0.5207309126853943)]
