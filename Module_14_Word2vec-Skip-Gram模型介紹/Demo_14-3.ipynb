# %% [markdown]
# # 產生word2vec訓練資料

# %%
from __future__ import print_function
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)

def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))

vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'as', 'term', 'of', 'originated']

# %% [markdown]
# # Word2vec模型建立

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From C:\Users\isaac\Anaconda3\envs\test\lib\site-packages\tensorflow_core\python\training\adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From <ipython-input-4-6cf1e824a44a>:48: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
              # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.994786
# Nearest to it: benedictine, entire, damascus, miscarriages, drivetrain, electrostatics, could, lebesgue,
# Nearest to most: bawerk, ratu, tabs, volkov, lint, enrollments, captaincy, references,
# Nearest to is: repressed, anthems, bedi, denver, columbo, nyse, boleyn, raiders,
# Nearest to i: pleas, primal, porters, abyssinian, cayman, dk, jstor, kwa,
# Nearest to use: thunderbolt, interpolant, chuan, cabo, wardrobe, continuous, sei, enchanter,
# Nearest to some: barbarous, barisan, protesting, upanishads, actinium, caxton, mutation, beck,
# Nearest to to: fondness, binary, listed, shading, singing, candida, mtp, concocted,
# Nearest to d: deceptively, phase, alessandri, aristotle, balance, centennial, plenipotentiary, grant,
# Nearest to s: invests, stansted, bankruptcies, lateran, machiavelli, whitehall, alo, moat,
# Nearest to an: observances, assented, kalevala, injective, howard, insurance, steyn, chordal,
# Nearest to used: exams, enrich, affairs, midi, sancho, compositional, denning, adjective,
# Nearest to state: pathogens, implosion, pearl, astbury, controls, intercalary, agincourt, digit,
# Nearest to all: rickshaw, proceed, detroit, agree, satirizes, rudy, hoof, embouchure,
# Nearest to over: dresden, aramaic, sicilian, musketeers, estates, vere, bucaram, relocation,
# Nearest to the: vice, heinemann, behaves, halloween, crediting, global, bacteria, remain,
# Nearest to his: sizable, theologically, precepts, jumper, squared, linguists, countrymen, floats,
# Average loss at step 2000: 4.359547
# Average loss at step 4000: 3.866278
# Average loss at step 6000: 3.791721
# Average loss at step 8000: 3.685866
# Average loss at step 10000: 3.617655
# Nearest to it: he, this, there, not, they, unjustly, that, nashville,
# Nearest to most: bawerk, tabs, linker, hinayana, emotionally, volkov, captaincy, all,
# Nearest to is: was, are, has, nonnegative, rubens, be, volumes, escrow,
# Nearest to i: petite, pleas, neberg, cayman, spoil, policeman, lilac, polarised,
# Nearest to use: interpolant, thunderbolt, bryson, transpersonal, liao, enchanter, platypus, compounded,
# Nearest to some: many, different, beck, various, lysander, our, their, its,
# Nearest to to: would, basses, resonate, not, may, can, garage, referenda,
# Nearest to d: ovarian, apatosaurus, grant, rematch, disturbing, hires, cautionary, deceptively,
# Nearest to s: his, b, sink, penh, springboard, rehab, lateran, clog,
# Nearest to an: fromm, drone, the, quarterback, nuclides, nutmeg, gallant, reform,
# Nearest to used: amazingly, relayed, duplications, referred, naacp, apparent, majorities, found,
# Nearest to state: pathogens, implosion, pearl, current, euskal, digit, mendes, astbury,
# Nearest to all: rudy, fell, detroit, stipulation, catolica, many, cannibals, embouchure,
# Nearest to over: dresden, aramaic, wa, posen, basis, estates, years, silverberg,
# Nearest to the: a, this, his, its, their, cronenberg, halloween, sturgis,
# Nearest to his: their, the, s, her, its, cronenberg, my, firefox,
# Average loss at step 12000: 3.608116
# Average loss at step 14000: 3.568778
# Average loss at step 16000: 3.408204
# Average loss at step 18000: 3.459615
# Average loss at step 20000: 3.538652
# Nearest to it: he, there, this, they, which, she, unjustly, not,
# Nearest to most: more, linker, some, bawerk, escorts, definability, tabs, among,
# Nearest to is: was, has, are, became, were, escrow, but, repressed,
# Nearest to i: petite, ii, moot, ramifications, porters, spoil, again, neberg,
# Nearest to use: interpolant, lack, inductive, transpersonal, liao, nagel, bryson, compounded,
# Nearest to some: many, these, their, its, various, different, all, most,
# Nearest to to: resonate, can, would, will, may, not, could, basses,
# Nearest to d: b, honeys, eight, disturbing, excretion, anacletus, rematch, dinners,
# Nearest to s: lateran, springboard, renewal, iho, mirrors, retake, filing, bahadur,
# Nearest to an: drone, cations, fooled, chiapas, womanhood, this, plundered, the,
# Nearest to used: found, referred, called, known, naacp, relayed, midi, spader,
# Nearest to state: pathogens, implosion, sicilian, current, euskal, member, shilton, goal,
# Nearest to all: many, these, rudy, some, detroit, stipulation, cannibals, asterism,
# Nearest to over: dresden, aramaic, pli, estates, maxim, wa, diana, posen,
# Nearest to the: its, their, his, any, a, this, flavour, some,
# Nearest to his: their, her, its, the, my, our, some, josip,
# Average loss at step 22000: 3.505082
# Average loss at step 24000: 3.488981
# Average loss at step 26000: 3.481321
# Average loss at step 28000: 3.479784
# Average loss at step 30000: 3.502411
# Nearest to it: he, there, this, they, she, unjustly, we, which,
# Nearest to most: more, among, many, some, escorts, bawerk, use, schiller,
# Nearest to is: was, has, are, became, does, but, be, were,
# Nearest to i: ii, petite, moot, ramifications, you, we, porters, they,
# Nearest to use: interpolant, lack, nagel, unlicensed, loss, kesey, inductive, mongol,
# Nearest to some: many, these, their, various, several, all, they, most,
# Nearest to to: would, resonate, can, must, basses, may, could, will,
# Nearest to d: b, participles, anacletus, madonna, earhart, hires, leaded, vi,
# Nearest to s: lateran, rehab, nudity, his, scorers, tokusatsu, arcadius, iho,
# Nearest to an: curl, drone, fooled, estrangement, plundered, this, entrance, contingents,
# Nearest to used: known, found, referred, given, naacp, considered, called, financi,
# Nearest to state: pathogens, implosion, goal, mendes, member, dysfunctional, nw, shilton,
# Nearest to all: some, these, many, several, any, stipulation, keenan, most,
# Nearest to over: dresden, pli, aramaic, estates, andrea, lovelace, ccf, angora,
# Nearest to the: their, its, his, her, akron, these, fond, some,
# Nearest to his: their, her, its, the, my, our, s, equally,
# Average loss at step 32000: 3.502088
# Average loss at step 34000: 3.490992
# Average loss at step 36000: 3.456604
# Average loss at step 38000: 3.303003
# Average loss at step 40000: 3.432061
# Nearest to it: he, there, she, this, they, which, not, never,
# Nearest to most: more, among, many, some, escorts, characterization, lovecraft, remorse,
# Nearest to is: was, has, are, became, if, be, campaigned, romantics,
# Nearest to i: ii, we, you, petite, moot, they, ramifications, he,
# Nearest to use: interpolant, lack, loss, unlicensed, nagel, belong, transpersonal, mandalay,
# Nearest to some: many, these, various, several, any, their, both, different,
# Nearest to to: can, would, resonate, will, antithetical, may, must, could,
# Nearest to d: b, UNK, participles, telethon, honeys, hires, meps, earhart,
# Nearest to s: tokusatsu, samuel, immunoglobulin, his, did, entrepot, penh, her,
# Nearest to an: fooled, nuclides, the, milligan, no, drone, gpmg, fromm,
# Nearest to used: found, referred, known, considered, given, classified, able, available,
# Nearest to state: mendes, implosion, dysfunctional, pathogens, goal, government, member, press,
# Nearest to all: some, any, nox, many, these, stipulation, catolica, writable,
# Nearest to over: outside, vessels, pli, keyser, dresden, andrea, aramaic, elaboration,
# Nearest to the: its, their, a, any, his, this, another, wildfire,
# Nearest to his: their, her, its, my, the, our, equally, gar,
# Average loss at step 42000: 3.436378
# Average loss at step 44000: 3.456610
# Average loss at step 46000: 3.449502
# Average loss at step 48000: 3.350860
# Average loss at step 50000: 3.383195
# Nearest to it: he, there, she, they, this, actually, then, still,
# Nearest to most: more, among, many, some, escorts, flame, remorse, yemen,
# Nearest to is: was, has, are, became, be, contains, happiness, makes,
# Nearest to i: ii, you, we, petite, they, townsend, he, moot,
# Nearest to use: interpolant, lack, loss, unlicensed, globus, cyclopentadienyl, mongol, belong,
# Nearest to some: many, these, several, various, any, most, both, all,
# Nearest to to: resonate, may, can, would, will, must, melle, antithetical,
# Nearest to d: b, honeys, meps, participles, hires, telethon, apatosaurus, earhart,
# Nearest to s: unfortunately, and, appealing, tokusatsu, voles, whose, hydrodynamics, lateran,
# Nearest to an: another, no, fooled, nuclides, lett, drone, gilbertese, unsure,
# Nearest to used: known, referred, given, found, considered, available, written, able,
# Nearest to state: implosion, mendes, press, dysfunctional, goal, member, pathogens, society,
# Nearest to all: both, many, some, every, barrett, arnaud, these, any,
# Nearest to over: through, dresden, outside, pli, keyser, andrea, vessels, countercult,
# Nearest to the: its, their, his, a, this, harum, some, hypopituitarism,
# Nearest to his: her, their, its, my, our, the, agility, your,
# Average loss at step 52000: 3.434396
# Average loss at step 54000: 3.426947
# Average loss at step 56000: 3.437832
# Average loss at step 58000: 3.394622
# Average loss at step 60000: 3.392057
# Nearest to it: there, he, she, this, which, they, now, then,
# Nearest to most: many, more, some, among, use, airspeed, flame, remorse,
# Nearest to is: was, are, has, happiness, be, contains, includes, retorted,
# Nearest to i: ii, we, you, petite, they, moot, townsend, ariosto,
# Nearest to use: interpolant, loss, lack, missions, most, unlicensed, history, globus,
# Nearest to some: many, several, these, any, most, various, all, the,
# Nearest to to: resonate, would, will, incorporates, intelligences, pillaged, might, antithetical,
# Nearest to d: b, h, meps, hires, deceptively, p, apatosaurus, j,
# Nearest to s: whose, lateran, aluminum, ray, fisheries, subtractive, penh, ivorian,
# Nearest to an: fooled, lucrezia, another, yauch, prelude, drone, novarum, cations,
# Nearest to used: referred, given, found, known, considered, available, defined, held,
# Nearest to state: press, implosion, goal, mendes, member, dysfunctional, states, government,
# Nearest to all: some, many, both, various, these, every, several, different,
# Nearest to over: through, outside, dresden, keyser, across, into, pli, between,
# Nearest to the: their, its, a, some, our, any, this, each,
# Nearest to his: her, their, its, my, our, gar, agility, the,
# Average loss at step 62000: 3.241340
# Average loss at step 64000: 3.254028
# Average loss at step 66000: 3.404844
# Average loss at step 68000: 3.394456
# Average loss at step 70000: 3.359001
# Nearest to it: he, she, there, this, they, we, never, still,
# Nearest to most: more, many, some, among, less, use, flame, commercially,
# Nearest to is: was, has, are, be, became, contains, makes, does,
# Nearest to i: ii, we, you, petite, townsend, moot, attracts, dieppe,
# Nearest to use: unlicensed, lack, loss, interpolant, missions, apply, most, because,
# Nearest to some: many, several, these, all, various, any, most, both,
# Nearest to to: will, would, can, resonate, must, melle, cannot, should,
# Nearest to d: b, h, meps, deceptively, p, l, moivre, hires,
# Nearest to s: approving, lateran, subtractive, tokusatsu, ray, whose, springboard, acetone,
# Nearest to an: fooled, cations, flutter, nuclides, the, another, drone, lett,
# Nearest to used: known, referred, found, available, given, written, considered, defined,
# Nearest to state: press, states, member, implosion, anal, niche, membership, government,
# Nearest to all: many, some, various, every, several, both, any, each,
# Nearest to over: keyser, through, across, outside, deliberative, holding, pli, territorial,
# Nearest to the: their, a, any, its, our, this, each, another,
# Nearest to his: her, their, its, my, our, agility, gar, the,
# Average loss at step 72000: 3.375411
# Average loss at step 74000: 3.352841
# Average loss at step 76000: 3.319680
# Average loss at step 78000: 3.353918
# Average loss at step 80000: 3.382464
# Nearest to it: he, there, she, this, they, thus, still, never,
# Nearest to most: many, some, more, among, less, use, yemen, flame,
# Nearest to is: was, has, are, although, gendered, involves, became, be,
# Nearest to i: ii, we, petite, iii, townsend, you, mckinley, ramifications,
# Nearest to use: interpolant, lack, unlicensed, loss, because, apply, most, start,
# Nearest to some: many, several, most, these, various, any, both, tabs,
# Nearest to to: would, resonate, melle, should, will, must, concocted, kolkata,
# Nearest to d: b, deceptively, h, p, l, meps, francis, dio,
# Nearest to s: entrepot, hydrodynamics, whose, ida, unfashionable, tokusatsu, fingering, machina,
# Nearest to an: nuclides, unhappiness, cations, forcible, drone, gilbertese, quarterback, steyn,
# Nearest to used: referred, known, found, given, written, available, considered, defined,
# Nearest to state: press, states, niche, city, mendes, dysfunctional, member, wenders,
# Nearest to all: both, every, many, several, various, any, each, yeshiva,
# Nearest to over: across, through, keyser, ecclesia, into, dresden, pli, odour,
# Nearest to the: its, their, this, harum, his, a, mosander, our,
# Nearest to his: her, their, its, my, our, your, headroom, gar,
# Average loss at step 82000: 3.403597
# Average loss at step 84000: 3.411470
# Average loss at step 86000: 3.387396
# Average loss at step 88000: 3.349400
# Average loss at step 90000: 3.365922
# Nearest to it: he, she, there, they, this, thus, itself, never,
# Nearest to most: more, many, some, less, among, use, especially, flame,
# Nearest to is: was, has, are, although, be, became, requires, appears,
# Nearest to i: ii, we, you, petite, iii, mckinley, townsend, landowners,
# Nearest to use: interpolant, unlicensed, lack, apply, find, missions, because, most,
# Nearest to some: many, several, any, these, most, this, all, various,
# Nearest to to: resonate, will, would, compactly, portsmouth, infielder, deportations, towards,
# Nearest to d: b, deceptively, h, apatosaurus, mustaine, l, six, cool,
# Nearest to s: lateran, whose, almagest, minuet, isbn, tokusatsu, his, hydrodynamics,
# Nearest to an: lucrezia, gilbertese, gpmg, entrance, unhappiness, another, volleys, drone,
# Nearest to used: known, referred, given, found, considered, available, applied, designed,
# Nearest to state: press, states, mendes, government, member, implosion, niche, city,
# Nearest to all: many, every, several, both, some, any, yeshiva, various,
# Nearest to over: through, vessels, across, keyser, off, pli, beyond, andrea,
# Nearest to the: its, his, their, this, any, a, our, your,
# Nearest to his: her, their, its, my, our, your, the, riverview,
# Average loss at step 92000: 3.392956
# Average loss at step 94000: 3.258585
# Average loss at step 96000: 3.359105
# Average loss at step 98000: 3.242606
# Average loss at step 100000: 3.356394
# Nearest to it: he, she, there, this, they, unclear, never, actually,
# Nearest to most: more, less, many, commercially, especially, some, among, yemen,
# Nearest to is: was, has, became, becomes, are, had, be, does,
# Nearest to i: we, ii, you, they, mckinley, landowners, townsend, petite,
# Nearest to use: interpolant, lack, form, unlicensed, apply, missions, loss, find,
# Nearest to some: many, several, these, any, certain, various, all, their,
# Nearest to to: will, would, could, should, can, resonate, melle, kolkata,
# Nearest to d: b, henley, h, p, deceptively, ruminants, footy, mustaine,
# Nearest to s: whose, his, my, entrepot, hydrodynamics, hedeby, tokusatsu, llewelyn,
# Nearest to an: another, gpmg, fooled, lucrezia, unsure, gilbertese, nuclides, assented,
# Nearest to used: referred, known, given, found, available, designed, considered, defined,
# Nearest to state: press, states, mendes, niche, coup, city, member, territory,
# Nearest to all: every, several, many, both, these, various, any, some,
# Nearest to over: through, across, andrea, around, vessels, into, within, beyond,
# Nearest to the: their, his, harum, its, a, her, our, your,
# Nearest to his: her, their, our, my, its, your, the, s,

# %% [markdown]
# # 可視化word2vec結果

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                        ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
